# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_data = pd.read_csv(mouse_drug_data_to_load)
trial_data = pd.read_csv(clinical_trial_data_to_load)

# Combine the data into a single dataset
all_data = pd.merge(mouse_data,trial_data,how = 'inner')

# Display the data table for preview
all_data.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
tumor = all_data.groupby(['Drug','Timepoint'])
average = tumor.mean()['Tumor Volume (mm3)']
# Convert to DataFrame
summary_table1 = pd.DataFrame(average)

# Preview DataFrame
summary_table1.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
from scipy.stats import sem
#summary_table1['Standard Error'] = summary_table1['Tumor Volume (mm3)'].sem()
tumor_standard_errors = tumor.sem()['Tumor Volume (mm3)']

# Convert to DataFrame
summary_table1_standard_errors = pd.DataFrame(tumor_standard_errors)

# Preview DataFrame
summary_table1_standard_errors = summary_table1_standard_errors.unstack(level = ['Drug'])
summary_table1_standard_errors = summary_table1_standard_errors.droplevel(level=0,axis=1)
summary_table1_standard_errors = pd.DataFrame(summary_table1_standard_errors)
summary_table1_standard_errors = summary_table1_standard_errors[['Capomulin','Infubinol',
                                                                'Ketapril','Placebo']]
summary_table1_standard_errors
# Out:
# Drug       Capomulin  Infubinol  Ketapril   Placebo
# Timepoint
# 0           0.000000   0.000000  0.000000  0.000000
# 5           0.448593   0.235102  0.264819  0.218091
# 10          0.702684   0.282346  0.357421  0.402064
# 15          0.838617   0.357705  0.580268  0.614461
# 20          0.909731   0.476210  0.726484  0.839609
# 25          0.881642   0.550315  0.755413  1.034872
# 30          0.934460   0.631061  0.934121  1.218231
# 35          1.052241   0.984155  1.127867  1.287481
# 40          1.223608   1.055220  1.158449  1.370634
# 45          1.223977   1.144427  1.453186  1.351726

# %%
# Minor Data Munging to Re-Format the Data Frames
summary_table1 = summary_table1.unstack(level = ['Drug'])
summary_table1 = summary_table1.droplevel(level=0,axis=1)
summary_table1 = pd.DataFrame(summary_table1)
# Preview that Reformatting worked
summary_table1
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
#Capomulin, Infubinol, Ketapril, and Placebo
summary_table2 = summary_table1[['Capomulin','Infubinol','Ketapril','Placebo']]
summary_table2
# Out:
# Drug       Capomulin  Infubinol   Ketapril    Placebo
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          44.266086  47.062001  47.389175  47.125589
# 10         43.084291  49.403909  49.582269  49.423329
# 15         42.064317  51.296397  52.399974  51.359742
# 20         40.716325  53.197691  54.920935  54.364417
# 25         39.939528  55.715252  57.678982  57.482574
# 30         38.769339  58.299397  60.994507  59.809063
# 35         37.816839  60.742461  63.371686  62.420615
# 40         36.958001  63.162824  66.068580  65.052675
# 45         36.236114  65.755562  70.662958  68.084082

# %%
# Generate the Plot (with Error Bars)
x_axis = summary_table2.index
data = summary_table2.columns
Capomulin = plt.errorbar(x_axis,summary_table2['Capomulin'],elinewidth= 0.5,yerr = summary_table1_standard_errors['Capomulin'],label='Capolumulin',marker='o',color = 'red'
                ,linestyle='dashed',linewidth=1)
Infubinol = plt.errorbar(x_axis,summary_table2['Infubinol'],elinewidth= 0.5,yerr = summary_table1_standard_errors['Infubinol'],label = 'Infubinol',marker='^',color = 'blue',
                linestyle='dashed',linewidth=1)
Ketapril = plt.errorbar(x_axis,summary_table2['Ketapril'],elinewidth= 0.5,yerr = summary_table1_standard_errors['Ketapril'],label = 'Ketapril',marker='s',color = 'green',
                linestyle='dashed',linewidth=1)
Placebo = plt.errorbar(x_axis,summary_table2['Placebo'],elinewidth= 0.5,yerr = summary_table1_standard_errors['Placebo'],label = 'Placebo',marker='D',color='black',
                linestyle='dashed',linewidth=1)
plt.legend(loc='upper left')
plt.xlabel("Treatment Period (Days)")
plt.ylabel("Tumor Volume(mm3)")
plt.title("Tumor Volume During Treatment")
plt.grid()
#plt.errorbar(x_axis,summary_table1_standard_errors)
# Save the Figure
plt.show()

# %%
# Show the Figure

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
meta = tumor.mean()['Metastatic Sites']
# Convert to DataFrame
meta_df = pd.DataFrame(meta)
# Preview DataFrame
meta_df.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
meta_standard_error = tumor.sem()['Metastatic Sites']
# Convert to DataFrame
meta_standard_error_df = pd.DataFrame(meta_standard_error)
# Preview DataFrame
meta_standard_error_df.head()
meta_standard_error_df = meta_standard_error_df.unstack(level = ['Drug'])
meta_standard_error_df = meta_standard_error_df.droplevel(level=0,axis=1)
meta_standard_error_df = pd.DataFrame(meta_standard_error_df)
meta_standard_error_df = meta_standard_error_df[['Capomulin','Infubinol',
                                                                'Ketapril','Placebo']]
meta_standard_error_df
# Out:
# Drug       Capomulin  Infubinol  Ketapril   Placebo
# Timepoint
# 0           0.000000   0.000000  0.000000  0.000000
# 5           0.074833   0.091652  0.098100  0.100947
# 10          0.125433   0.159364  0.142018  0.115261
# 15          0.132048   0.194015  0.191381  0.190221
# 20          0.161621   0.234801  0.236680  0.234064
# 25          0.181818   0.265753  0.288275  0.263888
# 30          0.172944   0.227823  0.347467  0.300264
# 35          0.169496   0.224733  0.361418  0.341412
# 40          0.175610   0.314466  0.315725  0.297294
# 45          0.202591   0.309320  0.278722  0.304240

# %%
# Minor Data Munging to Re-Format the Data Frames
meta_df = meta_df.unstack(level = ['Drug'])

# %%
meta_df = meta_df.droplevel(level=0,axis=1)
meta_df = pd.DataFrame(meta_df)
# Preview that Reformatting worked
meta_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
meta_df2=meta_df[['Capomulin','Infubinol','Ketapril','Placebo']]
meta_df2.head()
# Out:
# Drug       Capomulin  Infubinol  Ketapril   Placebo
# Timepoint
# 0           0.000000   0.000000  0.000000  0.000000
# 5           0.160000   0.280000  0.304348  0.375000
# 10          0.320000   0.666667  0.590909  0.833333
# 15          0.375000   0.904762  0.842105  1.250000
# 20          0.652174   1.050000  1.210526  1.526316

# %%
# Generate the Plot (with Error Bars)
x_axis = meta_df2.index
data = meta_df2.columns
Capomulin = plt.errorbar(x_axis,meta_df2['Capomulin'],elinewidth= 0.5,yerr = meta_standard_error_df['Capomulin'],label='Capolumulin',marker='o',color = 'red'
                ,linestyle='dashed',linewidth=1)
Infubinol = plt.errorbar(x_axis,meta_df2['Infubinol'],elinewidth= 0.5,yerr = meta_standard_error_df['Infubinol'],label = 'Infubinol',marker='^',color = 'blue',
                linestyle='dashed',linewidth=1)
Ketapril = plt.errorbar(x_axis,meta_df2['Ketapril'],elinewidth= 0.5,yerr = meta_standard_error_df['Ketapril'],label = 'Ketapril',marker='s',color = 'green',
                linestyle='dashed',linewidth=1)
Placebo = plt.errorbar(x_axis,meta_df2['Placebo'],elinewidth= 0.5,yerr = meta_standard_error_df['Placebo'],label = 'Placebo',marker='D',color='black',
                linestyle='dashed',linewidth=1)
plt.legend(loc='upper left')
plt.xlabel("Treatment Period (Days)")
plt.ylabel("Metastatic Sites")
plt.title('Metastatic Spread During Treatment')
plt.grid()
#plt.errorbar(x_axis,summary_table1_standard_errors)
# Save the Figure
plt.show()

# Show the Figure

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
survival = all_data.groupby(['Drug','Timepoint'])
mice_count = survival.count()['Mouse ID']
# Convert to DataFrame
survival_df = pd.DataFrame(mice_count)
# Preview DataFrame
survival_df.head()
# Out:
#                      Mouse ID
# Drug      Timepoint
# Capomulin 0                25
#           5                25
#           10               25
#           15               24
#           20               23

# %%
survival_df2 = survival_df.unstack(level = ['Drug'])
survival_df2 = survival_df2.droplevel(level=0,axis=1)

# %%
# Minor Data Munging to Re-Format the Data Frames
survival_df2 = pd.DataFrame(survival_df2)
# Preview that Reformatting worked
survival_df2.head()
# Preview the Data Frame
survival_new = survival_df2[['Capomulin','Infubinol','Ketapril','Placebo']]
survival_new['Capomulin %'] = 100*(survival_new['Capomulin']/25)
survival_new['Infubinol %'] = 100*(survival_new['Infubinol']/25)
survival_new['Ketapril %'] = 100*(survival_new['Ketapril']/25)
survival_new['Placebo %'] = 100*(survival_new['Placebo']/25)
survival_new
# Out:
# Drug       Capomulin  Infubinol  Ketapril  Placebo  Capomulin %  Infubinol %  \
# Timepoint
# 0                 25         25        25       25        100.0        100.0
# 5                 25         25        23       24        100.0        100.0
# 10                25         21        22       24        100.0         84.0
# 15                24         21        19       20         96.0         84.0
# 20                23         20        19       19         92.0         80.0
# 25                22         18        19       17         88.0         72.0
# 30                22         17        18       15         88.0         68.0
# 35                22         12        17       14         88.0         48.0
# 40                21         10        15       12         84.0         40.0
# 45                21          9        11       11         84.0         36.0
#
# Drug       Ketapril %  Placebo %
# Timepoint
# 0               100.0      100.0
# ...

# %%
# Generate the Plot (Accounting for percentages)
x_axis = survival_new.index
data = survival_new.columns
Capomulin = plt.errorbar(x_axis,survival_new['Capomulin %'],label='Capolumulin',marker='o',color = 'red'
                ,linestyle='dashed',linewidth=.5)
Infubinol = plt.errorbar(x_axis,survival_new['Infubinol %'],label = 'Infubinol',marker='^',color = 'blue',
                linestyle='dashed',linewidth=.5)
Ketapril = plt.errorbar(x_axis,survival_new['Ketapril %'],label = 'Ketapril',marker='s',color = 'green',
                linestyle='dashed',linewidth=.5)
Placebo = plt.errorbar(x_axis,survival_new['Placebo %'],label = 'Placebo',marker='D',color='black',
                linestyle='dashed',linewidth=.5)
plt.legend(loc='lower left')
plt.xlabel("Time (Days)")
plt.ylabel("Survival Rate (%)")
plt.title('Survival During Treatment')
plt.grid()
#plt.errorbar(x_axis,summary_table1_standard_errors)
# Save the Figure
plt.show()
# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
summary_table2

# Display the data to confirm
# Out:
# Drug       Capomulin  Infubinol   Ketapril    Placebo
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          44.266086  47.062001  47.389175  47.125589
# 10         43.084291  49.403909  49.582269  49.423329
# 15         42.064317  51.296397  52.399974  51.359742
# 20         40.716325  53.197691  54.920935  54.364417
# 25         39.939528  55.715252  57.678982  57.482574
# 30         38.769339  58.299397  60.994507  59.809063
# 35         37.816839  60.742461  63.371686  62.420615
# 40         36.958001  63.162824  66.068580  65.052675
# 45         36.236114  65.755562  70.662958  68.084082

# %%
change = []
change = (100*(summary_table2.iloc[0]-summary_table2.iloc[9])/-45)
change_df = pd.DataFrame(change)
change
# Out:
# Drug
# Capomulin   -19.475303
# Infubinol    46.123472
# Ketapril     57.028795
# Placebo      51.297960
# dtype: float64

# %%
#change_df = change_df.pivot()
#change_df
#= change_df.droplevel(level=0,axis=0)

# %%
# Store all Relevant Percent Changes into a Tuple
drug = ['Capomulin','Infubinol','Ketapril','Placebo']
x_axis = len(change_df)
color_list = ['r','b','b','b']
plt.bar(drug,change,align='edge',color = color_list )

plt.grid()
# Splice the data between passing and failing drugs

# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
